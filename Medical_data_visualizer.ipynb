# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Import data
df = pd.read_csv("medical_examination.csv")

# %%
#Viewing Datafile
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
#Add Column "overweight" which calculates the BMI of person
# BMI = weight(in kgs)/ (height(in mts)^2)
df["overweight"] = df["weight"]/(df["height"]**2)*10000

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
# ...

# %%
#If BMI is > 25 then the person is overweight. Use the value 0 for NOT overweight and the value 1 for overweight.
df['overweight'] = np.where(df["overweight"] > 25,1,0)

#another method for the same
# df.loc[~(df['overweight'] > 25), 'overweight'] = 0
# df.loc[df['overweight'] > 25, 'overweight'] = 1

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
# ...

# %%
# Normalize the data by making 0 always good and 1 always bad. If the value of cholesterol is 1, make the value 0. If the value is more than 1, make the value 1.

df.loc[df["cholesterol"]==1 , "cholesterol"]=0
df.loc[df["cholesterol"]>1 , "cholesterol"]=1

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            0     1
# 1          1  20228       1     156    85.0    140     90            1     1
# 2          2  18857       1     165    64.0    130     70            1     1
# 3          3  17623       2     169    82.0    150    100            0     1
# 4          4  17474       1     156    56.0    100     60            0     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            0     1
# 69996  99995  22601       1     158   126.0    140     90            1     2
# 69997  99996  19066       2     183   105.0    180     90            1     1
# 69998  99998  22431       1     163    72.0    135     80            0     2
# 69999  99999  20540       1     170    72.0    120     80            1     1
#
# ...

# %%
# Normalize the data by making 0 always good and 1 always bad. If the value of cholesterol is 1, make the value 0. If the value is more than 1, make the value 1.

df.loc[df["gluc"] == 1, "gluc"] = 0
df.loc[df["gluc"] > 1, "gluc"] = 1

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            0     0
# 1          1  20228       1     156    85.0    140     90            1     0
# 2          2  18857       1     165    64.0    130     70            1     0
# 3          3  17623       2     169    82.0    150    100            0     0
# 4          4  17474       1     156    56.0    100     60            0     0
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            0     0
# 69996  99995  22601       1     158   126.0    140     90            1     1
# 69997  99996  19066       2     183   105.0    180     90            1     0
# 69998  99998  22431       1     163    72.0    135     80            0     1
# 69999  99999  20540       1     170    72.0    120     80            1     0
#
# ...

# %%
# Create DataFrame for cat plot using `pd.melt` using just the values from 'cholesterol', 'gluc', 'smoke', 'alco', 'active', and 'overweight'.
df_cat=pd.melt(df,id_vars=["cardio"],value_vars=['cholesterol','gluc','smoke','alco','active','overweight'])

# %%
df_cat
# Out:
#         cardio     variable  value
# 0            0  cholesterol      0
# 1            1  cholesterol      1
# 2            1  cholesterol      1
# 3            1  cholesterol      0
# 4            0  cholesterol      0
# ...        ...          ...    ...
# 419995       0   overweight      1
# 419996       1   overweight      1
# 419997       1   overweight      1
# 419998       1   overweight      1
# 419999       0   overweight      0
#
# [420000 rows x 3 columns]

# %%
# Group and reformat the data to split it by 'cardio'. Show the counts of each feature. You will have to rename one of the columns for the catplot to work correctly.
g= df_cat.groupby(['cardio'])

# %%
for cardio, cardio_df in g:
    print(cardio)
    print(cardio_df)
# Out:
# 0
#         cardio     variable  value
# 0            0  cholesterol      0
# 4            0  cholesterol      0
# 5            0  cholesterol      1
# 6            0  cholesterol      1
# 8            0  cholesterol      0
# ...        ...          ...    ...
# 419987       0   overweight      0
# 419988       0   overweight      0
# 419991       0   overweight      1
# 419995       0   overweight      1
# 419999       0   overweight      0
#
# [210126 rows x 3 columns]
# 1
#         cardio     variable  value
# 1            1  cholesterol      1
# 2            1  cholesterol      1
# 3            1  cholesterol      0
# 7            1  cholesterol      1
# 15           1  cholesterol      0
# ...        ...          ...    ...
# 419993       1   overweight      0
# 419994       1   overweight      1
# 419996       1   overweight      1
# 419997       1   overweight      1
# 419998       1   overweight      1
#
# [209874 rows x 3 columns]

# %%
df_cat = df_cat.groupby(['cardio','variable','value'])['value'].count().reset_index(name="total")

# %%
df_cat
# Out:
#     cardio     variable  value  total
# 0        0       active      0   6378
# 1        0       active      1  28643
# 2        0         alco      0  33080
# 3        0         alco      1   1941
# 4        0  cholesterol      0  29330
# 5        0  cholesterol      1   5691
# 6        0         gluc      0  30894
# 7        0         gluc      1   4127
# 8        0   overweight      0  15915
# 9        0   overweight      1  19106
# 10       0        smoke      0  31781
# 11       0        smoke      1   3240
# 12       1       active      0   7361
# 13       1       active      1  27618
# 14       1         alco      0  33156
# 15       1         alco      1   1823
# 16       1  cholesterol      0  23055
# 17       1  cholesterol      1  11924
# 18       1         gluc      0  28585
# 19       1         gluc      1   6394
# 20       1   overweight      0  10539
# 21       1   overweight      1  24440
# 22       1        smoke      0  32050
# 23       1        smoke      1   2929

# %%
fig = sns.catplot(x='variable', y='total', hue='value',col='cardio', data=df_cat,kind='bar').fig

# %%
# diastolic pressure is higher than systolic (Keep the correct data with (df['ap_lo'] <= df['ap_hi']))
df[df['ap_lo'] <= df['ap_hi']]
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            0     0
# 1          1  20228       1     156    85.0    140     90            1     0
# 2          2  18857       1     165    64.0    130     70            1     0
# 3          3  17623       2     169    82.0    150    100            0     0
# 4          4  17474       1     156    56.0    100     60            0     0
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            0     0
# 69996  99995  22601       1     158   126.0    140     90            1     1
# 69997  99996  19066       2     183   105.0    180     90            1     0
# 69998  99998  22431       1     163    72.0    135     80            0     1
# 69999  99999  20540       1     170    72.0    120     80            1     0
#
# ...

# %%
#draw heat map
def draw_heat_map():
    df_heat = df[(df['ap_lo']<=df['ap_hi']) & 
                 (df['height'] >= df['height'].quantile(0.025)) & 
                 (df['height'] <= df['height'].quantile(0.975)) &
                 (df['weight'] >= df['weight'].quantile(0.025)) &
                 (df['weight'] <= df['weight'].quantile(0.025))
                ]
    # Calculate the correlation matrix
    corr = df_heat.corr()
    
    # Generate a mask for the upper triangle
    mask = np.triu(corr)
    
    # Set up the matplotlib figure
    fig, ax = plt.subplots(figsize=(11, 9))
    
    # Draw the heatmap with 'sns.heatmap()'
    cmap = sns.diverging_palette(230, 20, as_cmap=True)
    ax = sns.heatmap(
        corr,
        center=0.04,
        annot=True,
        fmt='.1f',
        mask=mask)
    
    # Do not modify the next two lines
    fig.savefig('heatmap.png')
    return fig

# %%
draw_heat_map()
